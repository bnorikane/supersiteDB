# %% [markdown]
# # ETL data for Supersite volunteers table
# - Supersite Chairs and Co-Chairs
# - Registrars
# - Greeters
# - Troubleshooters

# %%
import pandas as pd 
import sqlite3

# %%
odbcols = ['Role', 'Positionkey', 'Workingprecinct', 'Voterid',
       'Vanid', 'Precinctabbr', 'Precinct', 'Lastname',
       'Firstname', 'Preferred', 'Email', 'Phone', 'Mobilephone', 'Homephone',
       'Address', 'City', 'Zip', ]

odb = pd.read_excel('data/odb_full_20240129.xlsx', usecols=odbcols)
odb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563 entries, 0 to 562
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Role             563 non-null    object
#  1   Positionkey      563 non-null    object
#  2   Workingprecinct  563 non-null    int64
#  3   Voterid          563 non-null    int64
#  4   Vanid            563 non-null    int64
#  5   Precinctabbr     563 non-null    int64
#  6   Precinct         563 non-null    int64
#  7   Lastname         563 non-null    object
#  8   Firstname        563 non-null    object
#  9   Preferred        563 non-null    object
#  10  Email            549 non-null    object
#  11  Phone            526 non-null    float64
#  12  Mobilephone      324 non-null    float64
#  13  Homephone        317 non-null    float64
#  14  Address          563 non-null    object
#  15  City             563 non-null    object
#  16  Zip              563 non-null    int64
# ...

# %%
field_roles = ['AC', 'PCP', 'PSP', 'PH']

odb[odb['Role'].isin(field_roles)]
# Out:
#     Role Positionkey  Workingprecinct    Voterid     Vanid  Precinctabbr  \
# 31    AC    HDBOAC05       2181007829  602274041  12111038           829
# 32    AC    HDBOAC01       2184907857    8040827    964297           857
# 33    AC    HDBOAC02       2184907844    8033360    950270           844
# 34    AC    HDBOAC03       2181007847    8246083    957531           847
# 35    AC    HDBOAC04       2181007835    8024294   1017998           835
# ..   ...         ...              ...        ...       ...           ...
# 475   PH      PH0915       2154907915    8329038   3290655           915
# 476   PH      PH0915       2154907915    8426947   1113715           915
# 477  PSP      PSP305       2171207305    7915043   1069658           302
# 478  PSP      PSP506       2181207506  600212680   6713084           507
# 479  PSP      PSP833       2181007833    7944491   3369319           834
#
#        Precinct   Lastname  Firstname  Preferred                     Email  \
# ...

# %%
ccregcols = ['VANID', 'Precinct Number: 22Pct# ', 'Precinct Number: Area Code ',
       'VoterID: StateVoterID', 'Contact Name', 'Date Submitted',
       'Is New Contact', 'Caucus Chair: Do you wish to be a Caucus Chair?',
       'Caucus Secretary: Do you wish to be a Caucus Secretary?', 'Cell Phone',
       'Personal Email']

ccreg = pd.read_excel('data/OnlineFormsCustomQuestionsReport2024CaucusChairand-3994710436.xlsx')
ccreg.info()
ccreg.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 11 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   VANID                                                    133 non-null    int64
#  1   Precinct Number: 22Pct#                                  133 non-null    int64
#  2   Precinct Number: Area Code                               133 non-null    object
#  3   VoterID: StateVoterID                                    133 non-null    int64
#  4   Contact Name                                             133 non-null    object
#  5   Date Submitted                                           133 non-null    datetime64[ns]
#  6   Is New Contact                                           133 non-null    int64
#  7   Caucus Chair: Do you wish to be a Caucus Chair?          133 non-null    object
# ...

# %%
# ss2024 = pd.merge(ssgeo, vengdf, left_on='supersite', right_on='venue', how='left')
signups = pd.merge(odb, ccreg, left_on='Vanid', right_on='VANID', how='outer')
signups.info()
signups
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 28 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Role                                                     563 non-null    object
#  1   Positionkey                                              563 non-null    object
#  2   Workingprecinct                                          563 non-null    float64
#  3   Voterid                                                  563 non-null    float64
#  4   Vanid                                                    563 non-null    float64
#  5   Precinctabbr                                             563 non-null    float64
#  6   Precinct                                                 563 non-null    float64
#  7   Lastname                                                 563 non-null    object
# ...
